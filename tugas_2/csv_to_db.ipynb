# %%
import pandas as pd
import numpy as np
import sqlite3
from sqlalchemy import create_engine

# %% [markdown]
# ### csv to sqlite

# %%
### read data : 

product = pd.read_csv("data/product.csv")
city = pd.read_csv("data/city.csv")
dealer = pd.read_csv("data/dealer.csv")
transaction = pd.read_csv("data/transaction.csv")

# %%
product
# Out:
#     product_id     brand            model  body_type  year      price
# 0            1    Toyota     Toyota Yaris  Hatchback  2016  175000000
# 1            2    Toyota     Toyota Yaris  Hatchback  2018  215000000
# 2            3    Toyota     Toyota Yaris  Hatchback  2014  162000000
# 3            4    Toyota     Toyota Yaris  Hatchback  2020  220000000
# 4            5    Toyota     Toyota Yaris  Hatchback  2012  124000000
# 5            6    Toyota      Toyota Agya  Hatchback  2019  114000000
# 6            7    Toyota      Toyota Agya  Hatchback  2014   97000000
# 7            8    Toyota      Toyota Agya  Hatchback  2016  110000000
# 8            9    Toyota      Toyota Agya  Hatchback  2022  155500000
# 9           10    Toyota      Toyota Agya  Hatchback  2017  115500000
# 10          11    Toyota     Toyota Calya      Wagon  2019  130000000
# 11          12    Toyota     Toyota Calya      Wagon  2019  137000000
# ...

# %%
connection = sqlite3.connect("database/tugas2.db")
product.to_sql('product',connection,if_exists='replace',index=False)
city.to_sql('city',connection,if_exists='replace',index=False)
dealer.to_sql('dealer',connection,if_exists='replace',index=False)
transaction.to_sql('transaction',connection,if_exists='replace',index=False)

connection.close()

# %% [markdown]
# ### sqlite to postgres

# %%
# Connect to SQLite database
sqlite_engine = create_engine('sqlite:///database/tugas2.db')

# %%
transaction.head(0)
# Out:
# Empty DataFrame
# Columns: [transaksi_id, dealer_id, product_id, kota_id]
# Index: []
